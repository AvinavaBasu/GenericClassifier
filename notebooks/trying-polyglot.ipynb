# %%
# !which pip
# Out:
# //anaconda2/envs/generic-classifier/bin/pip

# %%
# %%bash
# export PATH="/usr/local/opt/icu4c/bin:$PATH"
# export ICU_VERSION=64.2
# export PYICU_INCLUDES=/usr/local/opt/icu4c/include
# export PYICU_LFLAGS=-L/usr/local/opt/icu4c/lib
# export PKG_CONFIG_PATH="/usr/local/opt/icu4c/lib/pkgconfig"
# pip install polyglot pyicu
# Out:
# Requirement already satisfied: polyglot in /anaconda2/envs/generic-classifier/lib/python3.6/site-packages (16.7.4)
# Collecting pyicu
#   Using cached https://files.pythonhosted.org/packages/e9/35/211ffb949c68e688ade7d40426de030a24eaec4b6c45330eeb9c0285f43a/PyICU-2.3.1.tar.gz
# Building wheels for collected packages: pyicu
#   Building wheel for pyicu (setup.py): started
#   Building wheel for pyicu (setup.py): finished with status 'error'
#   Running setup.py clean for pyicu
# Failed to build pyicu
# Installing collected packages: pyicu
#     Running setup.py install for pyicu: started
#     Running setup.py install for pyicu: finished with status 'error'
#   ERROR: Command errored out with exit status 1:
#    command: //anaconda2/envs/generic-classifier/bin/python -u -c 'import sys, setuptools, tokenize; sys.argv[0] = '"'"'/private/var/folders/sy/4jbsqvn94jldp3lj7fdqqskh0000gr/T/pip-install-h__cjgcs/pyicu/setup.py'"'"'; __file__='"'"'/private/var/folders/sy/4jbsqvn94jldp3lj7fdqqskh0000gr/T/pip-install-h__cjgcs/pyicu/setup.py'"'"';f=getattr(tokenize, '"'"'open'"'"', open)(__file__);code=f.read().replace('"'"'\r\n'"'"', '"'"'\n'"'"');f.close();exec(compile(code, __file__, '"'"'exec'"'"'))' bdist_wheel -d /private/var/folders/sy/4jbsqvn94jldp3lj7fdqqskh0000gr/T/pip-wheel-hpdnc67f --python-tag cp36
#        cwd: /private/var/folders/sy/4jbsqvn94jldp3lj7fdqqskh0000gr/T/pip-install-h__cjgcs/pyicu/
#   Complete output (155 lines):
#
#   Building PyICU 2.3.1 for ICU 64.2
#
#   (running 'icu-config --cxxflags --cppflags')
#   Adding CFLAGS="-std=c++11 -I/usr/local/Cellar/icu4c/64.2/include" from /usr/local/opt/icu4c/bin/icu-config
#   running bdist_wheel
#   running build
#   running build_py
#   creating build
#   creating build/lib.macosx-10.7-x86_64-3.6
#   copying PyICU.py -> build/lib.macosx-10.7-x86_64-3.6
#   creating build/lib.macosx-10.7-x86_64-3.6/icu
#   copying icu/__init__.py -> build/lib.macosx-10.7-x86_64-3.6/icu
#   running build_ext
#   building '_icu' extension
#   creating build/temp.macosx-10.7-x86_64-3.6
#   gcc -Wno-unused-result -Wsign-compare -Wunreachable-code -DNDEBUG -g -fwrapv -O3 -Wall -Wstrict-prototypes -I//anaconda2/envs/generic-classifier/include -arch x86_64 -I//anaconda2/envs/generic-classifier/include -arch x86_64 -I/usr/local/opt/icu4c/include -I//anaconda2/envs/generic-classifier/include/python3.6m -c _icu.cpp -o build/temp.macosx-10.7-x86_64-3.6/_icu.o -std=c++11 -I/usr/local/Cellar/icu4c/64.2/include -DPYICU_VER="2.3.1"
#   In file included from _icu.cpp:27:
#   In file included from ./common.h:107:
#   In file included from /usr/local/opt/icu4c/include/unicode/ucnv.h:53:
#   In file included from /usr/local/opt/icu4c/include/unicode/uenum.h:23:
#   /usr/local/opt/icu4c/include/unicode/localpointer.h:239:32: error: no template named 'unique_ptr' in namespace 'std'
#       explicit LocalPointer(std::unique_ptr<T> &&p)
#                             ~~~~~^
#   /usr/local/opt/icu4c/include/unicode/localpointer.h:273:37: error: no template named 'unique_ptr' in namespace 'std'
#       LocalPointer<T> &operator=(std::unique_ptr<T> &&p) U_NOEXCEPT {
#                                  ~~~~~^
#   /usr/local/opt/icu4c/include/unicode/localpointer.h:347:19: error: no template named 'unique_ptr' in namespace 'std'
#       operator std::unique_ptr<T> () && {
#                ~~~~~^
#   /usr/local/opt/icu4c/include/unicode/localpointer.h:420:30: error: no template named 'unique_ptr' in namespace 'std'
#       explicit LocalArray(std::unique_ptr<T[]> &&p)
#                           ~~~~~^
#   /usr/local/opt/icu4c/include/unicode/localpointer.h:454:35: error: no template named 'unique_ptr' in namespace 'std'
#       LocalArray<T> &operator=(std::unique_ptr<T[]> &&p) U_NOEXCEPT {
#                                ~~~~~^
#   /usr/local/opt/icu4c/include/unicode/localpointer.h:536:19: error: no template named 'unique_ptr' in namespace 'std'
#       operator std::unique_ptr<T[]> () && {
#                ~~~~~^
#   In file included from _icu.cpp:27:
#   In file included from ./common.h:107:
#   In file included from /usr/local/opt/icu4c/include/unicode/ucnv.h:53:
#   /usr/local/opt/icu4c/include/unicode/uenum.h:68:1: error: no template named 'unique_ptr' in namespace 'std'
#   U_DEFINE_LOCAL_OPEN_POINTER(LocalUEnumerationPointer, UEnumeration, uenum_close);
#   ^~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
#   /usr/local/opt/icu4c/include/unicode/localpointer.h:573:45: note: expanded from macro 'U_DEFINE_LOCAL_OPEN_POINTER'
#           explicit LocalPointerClassName(std::unique_ptr<Type, decltype(&closeFunction)> &&p) \
#                                          ~~~~~^
#   In file included from _icu.cpp:27:
#   In file included from ./common.h:107:
#   In file included from /usr/local/opt/icu4c/include/unicode/ucnv.h:53:
#   /usr/local/opt/icu4c/include/unicode/uenum.h:68:1: error: no template named 'unique_ptr' in namespace 'std'
#   U_DEFINE_LOCAL_OPEN_POINTER(LocalUEnumerationPointer, UEnumeration, uenum_close);
#   ^~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
#   /usr/local/opt/icu4c/include/unicode/localpointer.h:583:47: note: expanded from macro 'U_DEFINE_LOCAL_OPEN_POINTER'
#           LocalPointerClassName &operator=(std::unique_ptr<Type, decltype(&closeFunction)> &&p) { \
#                                            ~~~~~^
#   In file included from _icu.cpp:27:
#   In file included from ./common.h:107:
#   In file included from /usr/local/opt/icu4c/include/unicode/ucnv.h:53:
#   /usr/local/opt/icu4c/include/unicode/uenum.h:68:1: error: no template named 'unique_ptr' in namespace 'std'
#   U_DEFINE_LOCAL_OPEN_POINTER(LocalUEnumerationPointer, UEnumeration, uenum_close);
#   ^~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
#   /usr/local/opt/icu4c/include/unicode/localpointer.h:599:23: note: expanded from macro 'U_DEFINE_LOCAL_OPEN_POINTER'
#           operator std::unique_ptr<Type, decltype(&closeFunction)> () && { \
#                    ~~~~~^
#   In file included from _icu.cpp:27:
#   In file included from ./common.h:107:
#   /usr/local/opt/icu4c/include/unicode/ucnv.h:585:1: error: no template named 'unique_ptr' in namespace 'std'
#   U_DEFINE_LOCAL_OPEN_POINTER(LocalUConverterPointer, UConverter, ucnv_close);
#   ^~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
#   /usr/local/opt/icu4c/include/unicode/localpointer.h:573:45: note: expanded from macro 'U_DEFINE_LOCAL_OPEN_POINTER'
#           explicit LocalPointerClassName(std::unique_ptr<Type, decltype(&closeFunction)> &&p) \
#                                          ~~~~~^
#   In file included from _icu.cpp:27:
#   In file included from ./common.h:107:
#   /usr/local/opt/icu4c/include/unicode/ucnv.h:585:1: error: no template named 'unique_ptr' in namespace 'std'
#   U_DEFINE_LOCAL_OPEN_POINTER(LocalUConverterPointer, UConverter, ucnv_close);
#   ^~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
#   /usr/local/opt/icu4c/include/unicode/localpointer.h:583:47: note: expanded from macro 'U_DEFINE_LOCAL_OPEN_POINTER'
#           LocalPointerClassName &operator=(std::unique_ptr<Type, decltype(&closeFunction)> &&p) { \
#                                            ~~~~~^
#   In file included from _icu.cpp:27:
#   In file included from ./common.h:107:
#   /usr/local/opt/icu4c/include/unicode/ucnv.h:585:1: error: no template named 'unique_ptr' in namespace 'std'
#   U_DEFINE_LOCAL_OPEN_POINTER(LocalUConverterPointer, UConverter, ucnv_close);
#   ^~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
#   /usr/local/opt/icu4c/include/unicode/localpointer.h:599:23: note: expanded from macro 'U_DEFINE_LOCAL_OPEN_POINTER'
#           operator std::unique_ptr<Type, decltype(&closeFunction)> () && { \
#                    ~~~~~^
#   In file included from _icu.cpp:27:
#   In file included from ./common.h:108:
#   /usr/local/opt/icu4c/include/unicode/locid.h:1146:30: error: cannot initialize object parameter of type 'const icu_64::LocalPointerBase<icu_64::StringEnumeration>' with an expression of type 'LocalPointer<icu_64::StringEnumeration>'
#           const char* buffer = keys->next(&resultLength, status);
#                                ^~~~
#   In file included from _icu.cpp:27:
#   In file included from ./common.h:110:
#   In file included from /usr/local/opt/icu4c/include/unicode/resbund.h:53:
#   /usr/local/opt/icu4c/include/unicode/ures.h:264:1: error: no template named 'unique_ptr' in namespace 'std'
#   U_DEFINE_LOCAL_OPEN_POINTER(LocalUResourceBundlePointer, UResourceBundle, ures_close);
#   ^~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
#   /usr/local/opt/icu4c/include/unicode/localpointer.h:573:45: note: expanded from macro 'U_DEFINE_LOCAL_OPEN_POINTER'
#           explicit LocalPointerClassName(std::unique_ptr<Type, decltype(&closeFunction)> &&p) \
#                                          ~~~~~^
#   In file included from _icu.cpp:27:
#   In file included from ./common.h:110:
#   In file included from /usr/local/opt/icu4c/include/unicode/resbund.h:53:
#   /usr/local/opt/icu4c/include/unicode/ures.h:264:1: error: no template named 'unique_ptr' in namespace 'std'
#   U_DEFINE_LOCAL_OPEN_POINTER(LocalUResourceBundlePointer, UResourceBundle, ures_close);
#   ^~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
#   /usr/local/opt/icu4c/include/unicode/localpointer.h:583:47: note: expanded from macro 'U_DEFINE_LOCAL_OPEN_POINTER'
#           LocalPointerClassName &operator=(std::unique_ptr<Type, decltype(&closeFunction)> &&p) { \
#                                            ~~~~~^
#   In file included from _icu.cpp:27:
#   In file included from ./common.h:110:
#   In file included from /usr/local/opt/icu4c/include/unicode/resbund.h:53:
#   /usr/local/opt/icu4c/include/unicode/ures.h:264:1: error: no template named 'unique_ptr' in namespace 'std'
#   U_DEFINE_LOCAL_OPEN_POINTER(LocalUResourceBundlePointer, UResourceBundle, ures_close);
#   ^~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
#   /usr/local/opt/icu4c/include/unicode/localpointer.h:599:23: note: expanded from macro 'U_DEFINE_LOCAL_OPEN_POINTER'
#           operator std::unique_ptr<Type, decltype(&closeFunction)> () && { \
#                    ~~~~~^
#   In file included from _icu.cpp:27:
#   In file included from ./common.h:111:
#   In file included from /usr/local/opt/icu4c/include/unicode/calendar.h:40:
#   In file included from /usr/local/opt/icu4c/include/unicode/timezone.h:44:
#   /usr/local/opt/icu4c/include/unicode/ucal.h:740:1: error: no template named 'unique_ptr' in namespace 'std'
#   U_DEFINE_LOCAL_OPEN_POINTER(LocalUCalendarPointer, UCalendar, ucal_close);
#   ^~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
#   /usr/local/opt/icu4c/include/unicode/localpointer.h:573:45: note: expanded from macro 'U_DEFINE_LOCAL_OPEN_POINTER'
#           explicit LocalPointerClassName(std::unique_ptr<Type, decltype(&closeFunction)> &&p) \
#                                          ~~~~~^
#   In file included from _icu.cpp:27:
#   In file included from ./common.h:111:
#   In file included from /usr/local/opt/icu4c/include/unicode/calendar.h:40:
#   In file included from /usr/local/opt/icu4c/include/unicode/timezone.h:44:
#   /usr/local/opt/icu4c/include/unicode/ucal.h:740:1: error: no template named 'unique_ptr' in namespace 'std'
#   U_DEFINE_LOCAL_OPEN_POINTER(LocalUCalendarPointer, UCalendar, ucal_close);
#   ^~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
#   /usr/local/opt/icu4c/include/unicode/localpointer.h:583:47: note: expanded from macro 'U_DEFINE_LOCAL_OPEN_POINTER'
#           LocalPointerClassName &operator=(std::unique_ptr<Type, decltype(&closeFunction)> &&p) { \
#                                            ~~~~~^
#   In file included from _icu.cpp:27:
#   In file included from ./common.h:111:
#   In file included from /usr/local/opt/icu4c/include/unicode/calendar.h:40:
#   In file included from /usr/local/opt/icu4c/include/unicode/timezone.h:44:
#   /usr/local/opt/icu4c/include/unicode/ucal.h:740:1: error: no template named 'unique_ptr' in namespace 'std'
#   U_DEFINE_LOCAL_OPEN_POINTER(LocalUCalendarPointer, UCalendar, ucal_close);
#   ^~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
#   /usr/local/opt/icu4c/include/unicode/localpointer.h:599:23: note: expanded from macro 'U_DEFINE_LOCAL_OPEN_POINTER'
#           operator std::unique_ptr<Type, decltype(&closeFunction)> () && { \
#                    ~~~~~^
#   fatal error: too many errors emitted, stopping now [-ferror-limit=]
#   20 errors generated.
#   error: command 'gcc' failed with exit status 1
#   ----------------------------------------
#   ERROR: Failed building wheel for pyicu
#     ERROR: Command errored out with exit status 1:
#      command: //anaconda2/envs/generic-classifier/bin/python -u -c 'import sys, setuptools, tokenize; sys.argv[0] = '"'"'/private/var/folders/sy/4jbsqvn94jldp3lj7fdqqskh0000gr/T/pip-install-h__cjgcs/pyicu/setup.py'"'"'; __file__='"'"'/private/var/folders/sy/4jbsqvn94jldp3lj7fdqqskh0000gr/T/pip-install-h__cjgcs/pyicu/setup.py'"'"';f=getattr(tokenize, '"'"'open'"'"', open)(__file__);code=f.read().replace('"'"'\r\n'"'"', '"'"'\n'"'"');f.close();exec(compile(code, __file__, '"'"'exec'"'"'))' install --record /private/var/folders/sy/4jbsqvn94jldp3lj7fdqqskh0000gr/T/pip-record-fdcb0qgd/install-record.txt --single-version-externally-managed --compile
#          cwd: /private/var/folders/sy/4jbsqvn94jldp3lj7fdqqskh0000gr/T/pip-install-h__cjgcs/pyicu/
#     Complete output (155 lines):
#
#     Building PyICU 2.3.1 for ICU 64.2
#
#     (running 'icu-config --cxxflags --cppflags')
#     Adding CFLAGS="-std=c++11 -I/usr/local/Cellar/icu4c/64.2/include" from /usr/local/opt/icu4c/bin/icu-config
#     running install
#     running build
#     running build_py
#     creating build
#     creating build/lib.macosx-10.7-x86_64-3.6
#     copying PyICU.py -> build/lib.macosx-10.7-x86_64-3.6
#     creating build/lib.macosx-10.7-x86_64-3.6/icu
#     copying icu/__init__.py -> build/lib.macosx-10.7-x86_64-3.6/icu
#     running build_ext
#     building '_icu' extension
#     creating build/temp.macosx-10.7-x86_64-3.6
#     gcc -Wno-unused-result -Wsign-compare -Wunreachable-code -DNDEBUG -g -fwrapv -O3 -Wall -Wstrict-prototypes -I//anaconda2/envs/generic-classifier/include -arch x86_64 -I//anaconda2/envs/generic-classifier/include -arch x86_64 -I/usr/local/opt/icu4c/include -I//anaconda2/envs/generic-classifier/include/python3.6m -c _icu.cpp -o build/temp.macosx-10.7-x86_64-3.6/_icu.o -std=c++11 -I/usr/local/Cellar/icu4c/64.2/include -DPYICU_VER="2.3.1"
#     In file included from _icu.cpp:27:
#     In file included from ./common.h:107:
#     In file included from /usr/local/opt/icu4c/include/unicode/ucnv.h:53:
#     In file included from /usr/local/opt/icu4c/include/unicode/uenum.h:23:
#     /usr/local/opt/icu4c/include/unicode/localpointer.h:239:32: error: no template named 'unique_ptr' in namespace 'std'
#         explicit LocalPointer(std::unique_ptr<T> &&p)
#                               ~~~~~^
#     /usr/local/opt/icu4c/include/unicode/localpointer.h:273:37: error: no template named 'unique_ptr' in namespace 'std'
#         LocalPointer<T> &operator=(std::unique_ptr<T> &&p) U_NOEXCEPT {
#                                    ~~~~~^
#     /usr/local/opt/icu4c/include/unicode/localpointer.h:347:19: error: no template named 'unique_ptr' in namespace 'std'
#         operator std::unique_ptr<T> () && {
#                  ~~~~~^
#     /usr/local/opt/icu4c/include/unicode/localpointer.h:420:30: error: no template named 'unique_ptr' in namespace 'std'
#         explicit LocalArray(std::unique_ptr<T[]> &&p)
#                             ~~~~~^
#     /usr/local/opt/icu4c/include/unicode/localpointer.h:454:35: error: no template named 'unique_ptr' in namespace 'std'
#         LocalArray<T> &operator=(std::unique_ptr<T[]> &&p) U_NOEXCEPT {
#                                  ~~~~~^
#     /usr/local/opt/icu4c/include/unicode/localpointer.h:536:19: error: no template named 'unique_ptr' in namespace 'std'
#         operator std::unique_ptr<T[]> () && {
#                  ~~~~~^
#     In file included from _icu.cpp:27:
#     In file included from ./common.h:107:
#     In file included from /usr/local/opt/icu4c/include/unicode/ucnv.h:53:
#     /usr/local/opt/icu4c/include/unicode/uenum.h:68:1: error: no template named 'unique_ptr' in namespace 'std'
#     U_DEFINE_LOCAL_OPEN_POINTER(LocalUEnumerationPointer, UEnumeration, uenum_close);
#     ^~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
#     /usr/local/opt/icu4c/include/unicode/localpointer.h:573:45: note: expanded from macro 'U_DEFINE_LOCAL_OPEN_POINTER'
#             explicit LocalPointerClassName(std::unique_ptr<Type, decltype(&closeFunction)> &&p) \
#                                            ~~~~~^
#     In file included from _icu.cpp:27:
#     In file included from ./common.h:107:
#     In file included from /usr/local/opt/icu4c/include/unicode/ucnv.h:53:
#     /usr/local/opt/icu4c/include/unicode/uenum.h:68:1: error: no template named 'unique_ptr' in namespace 'std'
#     U_DEFINE_LOCAL_OPEN_POINTER(LocalUEnumerationPointer, UEnumeration, uenum_close);
#     ^~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
#     /usr/local/opt/icu4c/include/unicode/localpointer.h:583:47: note: expanded from macro 'U_DEFINE_LOCAL_OPEN_POINTER'
#             LocalPointerClassName &operator=(std::unique_ptr<Type, decltype(&closeFunction)> &&p) { \
#                                              ~~~~~^
#     In file included from _icu.cpp:27:
#     In file included from ./common.h:107:
#     In file included from /usr/local/opt/icu4c/include/unicode/ucnv.h:53:
#     /usr/local/opt/icu4c/include/unicode/uenum.h:68:1: error: no template named 'unique_ptr' in namespace 'std'
#     U_DEFINE_LOCAL_OPEN_POINTER(LocalUEnumerationPointer, UEnumeration, uenum_close);
#     ^~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
#     /usr/local/opt/icu4c/include/unicode/localpointer.h:599:23: note: expanded from macro 'U_DEFINE_LOCAL_OPEN_POINTER'
#             operator std::unique_ptr<Type, decltype(&closeFunction)> () && { \
#                      ~~~~~^
#     In file included from _icu.cpp:27:
#     In file included from ./common.h:107:
#     /usr/local/opt/icu4c/include/unicode/ucnv.h:585:1: error: no template named 'unique_ptr' in namespace 'std'
#     U_DEFINE_LOCAL_OPEN_POINTER(LocalUConverterPointer, UConverter, ucnv_close);
#     ^~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
#     /usr/local/opt/icu4c/include/unicode/localpointer.h:573:45: note: expanded from macro 'U_DEFINE_LOCAL_OPEN_POINTER'
#             explicit LocalPointerClassName(std::unique_ptr<Type, decltype(&closeFunction)> &&p) \
#                                            ~~~~~^
#     In file included from _icu.cpp:27:
#     In file included from ./common.h:107:
#     /usr/local/opt/icu4c/include/unicode/ucnv.h:585:1: error: no template named 'unique_ptr' in namespace 'std'
#     U_DEFINE_LOCAL_OPEN_POINTER(LocalUConverterPointer, UConverter, ucnv_close);
#     ^~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
#     /usr/local/opt/icu4c/include/unicode/localpointer.h:583:47: note: expanded from macro 'U_DEFINE_LOCAL_OPEN_POINTER'
#             LocalPointerClassName &operator=(std::unique_ptr<Type, decltype(&closeFunction)> &&p) { \
#                                              ~~~~~^
#     In file included from _icu.cpp:27:
#     In file included from ./common.h:107:
#     /usr/local/opt/icu4c/include/unicode/ucnv.h:585:1: error: no template named 'unique_ptr' in namespace 'std'
#     U_DEFINE_LOCAL_OPEN_POINTER(LocalUConverterPointer, UConverter, ucnv_close);
#     ^~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
#     /usr/local/opt/icu4c/include/unicode/localpointer.h:599:23: note: expanded from macro 'U_DEFINE_LOCAL_OPEN_POINTER'
#             operator std::unique_ptr<Type, decltype(&closeFunction)> () && { \
#                      ~~~~~^
#     In file included from _icu.cpp:27:
#     In file included from ./common.h:108:
#     /usr/local/opt/icu4c/include/unicode/locid.h:1146:30: error: cannot initialize object parameter of type 'const icu_64::LocalPointerBase<icu_64::StringEnumeration>' with an expression of type 'LocalPointer<icu_64::StringEnumeration>'
#             const char* buffer = keys->next(&resultLength, status);
#                                  ^~~~
#     In file included from _icu.cpp:27:
#     In file included from ./common.h:110:
#     In file included from /usr/local/opt/icu4c/include/unicode/resbund.h:53:
#     /usr/local/opt/icu4c/include/unicode/ures.h:264:1: error: no template named 'unique_ptr' in namespace 'std'
#     U_DEFINE_LOCAL_OPEN_POINTER(LocalUResourceBundlePointer, UResourceBundle, ures_close);
#     ^~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
#     /usr/local/opt/icu4c/include/unicode/localpointer.h:573:45: note: expanded from macro 'U_DEFINE_LOCAL_OPEN_POINTER'
#             explicit LocalPointerClassName(std::unique_ptr<Type, decltype(&closeFunction)> &&p) \
#                                            ~~~~~^
#     In file included from _icu.cpp:27:
#     In file included from ./common.h:110:
#     In file included from /usr/local/opt/icu4c/include/unicode/resbund.h:53:
#     /usr/local/opt/icu4c/include/unicode/ures.h:264:1: error: no template named 'unique_ptr' in namespace 'std'
#     U_DEFINE_LOCAL_OPEN_POINTER(LocalUResourceBundlePointer, UResourceBundle, ures_close);
#     ^~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
#     /usr/local/opt/icu4c/include/unicode/localpointer.h:583:47: note: expanded from macro 'U_DEFINE_LOCAL_OPEN_POINTER'
#             LocalPointerClassName &operator=(std::unique_ptr<Type, decltype(&closeFunction)> &&p) { \
#                                              ~~~~~^
#     In file included from _icu.cpp:27:
#     In file included from ./common.h:110:
#     In file included from /usr/local/opt/icu4c/include/unicode/resbund.h:53:
#     /usr/local/opt/icu4c/include/unicode/ures.h:264:1: error: no template named 'unique_ptr' in namespace 'std'
#     U_DEFINE_LOCAL_OPEN_POINTER(LocalUResourceBundlePointer, UResourceBundle, ures_close);
#     ^~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
#     /usr/local/opt/icu4c/include/unicode/localpointer.h:599:23: note: expanded from macro 'U_DEFINE_LOCAL_OPEN_POINTER'
#             operator std::unique_ptr<Type, decltype(&closeFunction)> () && { \
#                      ~~~~~^
#     In file included from _icu.cpp:27:
#     In file included from ./common.h:111:
#     In file included from /usr/local/opt/icu4c/include/unicode/calendar.h:40:
#     In file included from /usr/local/opt/icu4c/include/unicode/timezone.h:44:
#     /usr/local/opt/icu4c/include/unicode/ucal.h:740:1: error: no template named 'unique_ptr' in namespace 'std'
#     U_DEFINE_LOCAL_OPEN_POINTER(LocalUCalendarPointer, UCalendar, ucal_close);
#     ^~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
#     /usr/local/opt/icu4c/include/unicode/localpointer.h:573:45: note: expanded from macro 'U_DEFINE_LOCAL_OPEN_POINTER'
#             explicit LocalPointerClassName(std::unique_ptr<Type, decltype(&closeFunction)> &&p) \
#                                            ~~~~~^
#     In file included from _icu.cpp:27:
#     In file included from ./common.h:111:
#     In file included from /usr/local/opt/icu4c/include/unicode/calendar.h:40:
#     In file included from /usr/local/opt/icu4c/include/unicode/timezone.h:44:
#     /usr/local/opt/icu4c/include/unicode/ucal.h:740:1: error: no template named 'unique_ptr' in namespace 'std'
#     U_DEFINE_LOCAL_OPEN_POINTER(LocalUCalendarPointer, UCalendar, ucal_close);
#     ^~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
#     /usr/local/opt/icu4c/include/unicode/localpointer.h:583:47: note: expanded from macro 'U_DEFINE_LOCAL_OPEN_POINTER'
#             LocalPointerClassName &operator=(std::unique_ptr<Type, decltype(&closeFunction)> &&p) { \
#                                              ~~~~~^
#     In file included from _icu.cpp:27:
#     In file included from ./common.h:111:
#     In file included from /usr/local/opt/icu4c/include/unicode/calendar.h:40:
#     In file included from /usr/local/opt/icu4c/include/unicode/timezone.h:44:
#     /usr/local/opt/icu4c/include/unicode/ucal.h:740:1: error: no template named 'unique_ptr' in namespace 'std'
#     U_DEFINE_LOCAL_OPEN_POINTER(LocalUCalendarPointer, UCalendar, ucal_close);
#     ^~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
#     /usr/local/opt/icu4c/include/unicode/localpointer.h:599:23: note: expanded from macro 'U_DEFINE_LOCAL_OPEN_POINTER'
#             operator std::unique_ptr<Type, decltype(&closeFunction)> () && { \
#                      ~~~~~^
#     fatal error: too many errors emitted, stopping now [-ferror-limit=]
#     20 errors generated.
#     error: command 'gcc' failed with exit status 1
#     ----------------------------------------
# ERROR: Command errored out with exit status 1: //anaconda2/envs/generic-classifier/bin/python -u -c 'import sys, setuptools, tokenize; sys.argv[0] = '"'"'/private/var/folders/sy/4jbsqvn94jldp3lj7fdqqskh0000gr/T/pip-install-h__cjgcs/pyicu/setup.py'"'"'; __file__='"'"'/private/var/folders/sy/4jbsqvn94jldp3lj7fdqqskh0000gr/T/pip-install-h__cjgcs/pyicu/setup.py'"'"';f=getattr(tokenize, '"'"'open'"'"', open)(__file__);code=f.read().replace('"'"'\r\n'"'"', '"'"'\n'"'"');f.close();exec(compile(code, __file__, '"'"'exec'"'"'))' install --record /private/var/folders/sy/4jbsqvn94jldp3lj7fdqqskh0000gr/T/pip-record-fdcb0qgd/install-record.txt --single-version-externally-managed --compile Check the logs for full command output.
# ---------------------------------------------------------------------------
# CalledProcessError                        Traceback (most recent call last)
# <ipython-input-5-abe62e0dac3e> in <module>
# ----> 1 get_ipython().run_cell_magic('bash', '', 'export PATH="/usr/local/opt/icu4c/bin:$PATH"\nexport ICU_VERSION=64.2\nexport PYICU_INCLUDES=/usr/local/opt/icu4c/include\nexport PYICU_LFLAGS=-L/usr/local/opt/icu4c/lib\nexport PKG_CONFIG_PATH="/usr/local/opt/icu4c/lib/pkgconfig"\npip install polyglot pyicu\n')
#
# //anaconda2/envs/generic-classifier/lib/python3.6/site-packages/IPython/core/interactiveshell.py in run_cell_magic(self, magic_name, line, cell)
#    2357             with self.builtin_trap:
#    2358                 args = (magic_arg_s, cell)
# -> 2359                 result = fn(*args, **kwargs)
#    2360             return result
#    2361
#
# //anaconda2/envs/generic-classifier/lib/python3.6/site-packages/IPython/core/magics/script.py in named_script_magic(line, cell)
#     140             else:
#     141                 line = script
# --> 142             return self.shebang(line, cell)
#     143
#     144         # write a basic docstring:
#
# <//anaconda2/envs/generic-classifier/lib/python3.6/site-packages/decorator.py:decorator-gen-110> in shebang(self, line, cell)
#
# //anaconda2/envs/generic-classifier/lib/python3.6/site-packages/IPython/core/magic.py in <lambda>(f, *a, **k)
#     185     # but it's overkill for just that one bit of state.
#     186     def magic_deco(arg):
# --> 187         call = lambda f, *a, **k: f(*a, **k)
#     188
#     189         if callable(arg):
#
# //anaconda2/envs/generic-classifier/lib/python3.6/site-packages/IPython/core/magics/script.py in shebang(self, line, cell)
#     243             sys.stderr.flush()
#     244         if args.raise_error and p.returncode!=0:
# --> 245             raise CalledProcessError(p.returncode, cell, output=out, stderr=err)
#     246
#     247     def _run_script(self, p, cell, to_close):
#
# CalledProcessError: Command 'b'export PATH="/usr/local/opt/icu4c/bin:$PATH"\nexport ICU_VERSION=64.2\nexport PYICU_INCLUDES=/usr/local/opt/icu4c/include\nexport PYICU_LFLAGS=-L/usr/local/opt/icu4c/lib\nexport PKG_CONFIG_PATH="/usr/local/opt/icu4c/lib/pkgconfig"\npip install polyglot pyicu\n'' returned non-zero exit status 1.

# %%
# !polyglot download embeddings2.en ner2.en
# Out:
# Traceback (most recent call last):
#   File "//anaconda2/envs/generic-classifier/bin/polyglot", line 5, in <module>
#     from polyglot.__main__ import main
#   File "//anaconda2/envs/generic-classifier/lib/python3.6/site-packages/polyglot/__main__.py", line 16, in <module>
#     from icu import Locale
# ModuleNotFoundError: No module named 'icu'

# %%
from polyglot.text import Text

# %%
blob = """The Israeli Prime Minister Benjamin Netanyahu has warned that Iran poses a "threat to the entire world"."""
text = Text(blob)

# We can also specify language of that text by using
# text = Text(blob, hint_language_code='en')
